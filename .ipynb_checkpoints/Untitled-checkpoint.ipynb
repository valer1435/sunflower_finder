# %%
import numpy as np
import os
from matplotlib.image import imread
# plants = open("plants.csv", "w+")
# sunflowers_dic = "sunflowerFieldsContours"
# nosunflowers_dic = "nosunflowerFieldsContours"
# max_ex = 20433
# cnt = 0
# for image in os.listdir(sunflowers_dic):
#     img =imread(sunflowers_dic+os.sep+image)
#     img = np.reshape(img, (1, img.shape[0]*img.shape[1]*3))
#     img = np.append(img, 1)
#     row = str(img[0])
#     for i in img[1::]:
#         row+=" "+str(i)
#     plants.write(row)
#     plants.write("\n")
#     cnt+=1
#     if cnt >=20433:
#         break

# %%
# for image in os.listdir(nosunflowers_dic):
#     img =imread(nosunflowers_dic+os.sep+image)
#     img = np.reshape(img, (1, img.shape[0]*img.shape[1]*3))
#     img = np.append(img, 0)
#     row = str(img[0])
#     for i in img[1::]:
#         row+=" "+str(i)
#     plants.write(row)
#     plants.write("\n")
# plants.close()

# %%
import pandas as pd
data = pd.read_csv("plants.csv", sep=" ", header=None)

# %%
data = data.sample(frac=1, replace=True, random_state=1)
data
# Out:
#             0         1         2         3         4         5         6    \
# 33003  0.466667  0.486275  0.462745  0.466667  0.486275  0.462745  0.482353
# 12172  0.741176  0.694118  0.403922  0.721569  0.674510  0.388235  0.674510
# 5192   0.654902  0.623529  0.290196  0.788235  0.737255  0.380392  0.913725
# 32511  0.494118  0.533333  0.501961  0.494118  0.533333  0.501961  0.505882
# 7813   0.600000  0.490196  0.098039  0.643137  0.521569  0.125490  0.721569
# 21440  0.490196  0.513726  0.470588  0.329412  0.329412  0.313726  0.282353
# 32912  0.521569  0.658824  0.541176  0.517647  0.654902  0.537255  0.509804
# 20609  0.513726  0.592157  0.486275  0.513726  0.592157  0.486275  0.525490
# 7751   0.545098  0.572549  0.305882  0.588235  0.603922  0.321569  0.615686
# 31228  0.470588  0.466667  0.486275  0.470588  0.466667  0.486275  0.482353
# 36230  0.431373  0.505882  0.419608  0.474510  0.568627  0.462745  0.521569
# 32025  0.486275  0.564706  0.454902  0.564706  0.666667  0.517647  0.603922
# 21758  0.498039  0.549020  0.478431  0.498039  0.549020  0.478431  0.505882
# 35730  0.427451  0.513726  0.372549  0.427451  0.513726  0.372549  0.443137
# 8444   0.192157  0.231373  0.207843  0.305882  0.337255  0.250980  0.435294
# 19946  0.258824  0.219608  0.000000  0.349020  0.301961  0.019608  0.486275
# 37532  0.517647  0.623529  0.462745  0.517647  0.623529  0.462745  0.529412
# 22926  0.435294  0.490196  0.431373  0.423529  0.482353  0.419608  0.400000
# 27204  0.552941  0.623529  0.529412  0.552941  0.623529  0.529412  0.560784
# 31959  0.254902  0.262745  0.239216  0.305882  0.309804  0.282353  0.400000
# 24535  0.376471  0.509804  0.364706  0.376471  0.509804  0.364706  0.372549
# 19433  0.580392  0.568627  0.349020  0.619608  0.603922  0.372549  0.701961
# 17137  0.529412  0.431373  0.117647  0.643137  0.541176  0.203922  0.811765
# 15781  0.658824  0.733333  0.584314  0.572549  0.650980  0.513726  1.0
# 40678  0.474510  0.541176  0.466667  0.466667  0.533333  0.462745  0.0
# 33004  0.458824  0.627451  0.447059  0.458824  0.627451  0.447059  0.0
# 20903  0.298039  0.337255  0.305882  0.301961  0.341176  0.309804  0.0
# 15258  0.250980  0.298039  0.035294  0.200000  0.243137  0.000000  1.0
# 40477  0.576471  0.623529  0.576471  0.576471  0.623529  0.576471  0.0
# 465    0.207843  0.243137  0.000000  0.141176  0.180392  0.000000  1.0
# 7220   0.847059  0.878431  0.462745  0.796078  0.827451  0.431373  1.0
#
# [40876 rows x 676 columns]

# %%
import torch


# determine the supported device

def get_device():
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu') # don't have GPU 
    return device

# convert a df to tensor to be used in pytorch
def df_to_tensor(df):
    device = get_device()
    return torch.from_numpy(df.values).float().to(device)
params = data.iloc[:, 0:-1].copy()

target = data.iloc[:, -1].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fc03abb77104> in <module>
#      15     device = get_device()
#      16     return torch.from_numpy(df.values).float().to(device)
# ---> 17 params = data.iloc[:, 0:-1].copy()
#      18
#      19 target = data.iloc[:, -1].copy()
#
# NameError: name 'data' is not defined

# %%
params = df_to_tensor(params)
target = df_to_tensor(target)
dataset_length = params.size()[0]
print((dataset_length* 0.60)//1)
train_x = params[: int(dataset_length* 0.60)]
valid_x = params[int(dataset_length* 0.60): int(dataset_length* 0.80)]
test_x = params[int(dataset_length* 0.80):]

train_y = target[: int(dataset_length* 0.60)]
valid_y = target[int(dataset_length* 0.60): int(dataset_length* 0.80)]
test_y = target[int(dataset_length* 0.80):]
# Out:
# 24525.0

# %%
import torch.utils.data
batch_size = 64

INPUT_SIZE = train_x.size()[1]
OUTPUT_SIZE = 1

train_tensor = torch.utils.data.TensorDataset(train_x, train_y) 
train_loader = torch.utils.data.DataLoader(dataset = train_tensor, batch_size = batch_size, shuffle = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f89f1c1b326f> in <module>
#       2 batch_size = 64
#       3
# ----> 4 train_tensor = torch.utils.data.TensorDataset(train_x, train_y)
#       5 train_loader = torch.utils.data.DataLoader(dataset = train_tensor, batch_size = batch_size, shuffle = True)
#       6
#
# NameError: name 'train_x' is not defined

# %%
import torch.nn as nn
import torch.nn.functional as F

class SunflowerFullConnectedClassificator(nn.Module):
    def __init__(self, input_size, output_size):
        super(SunflowerFullConnectedClassificator, self).__init__()
        self.fc1 = nn.Linear(input_size, 200)
        self.fc2 = nn.Linear(200, 200)
        self.fc3 = nn.Linear(200, output_size)

        
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %%
import torch.optim as optim
learning_rate = 0.003
epochs = 100


net = SunflowerFullConnectedClassificator(INPUT_SIZE, OUTPUT_SIZE)
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.05)
criterion = nn.BCEWithLogitsLoss()
loss_arr = []
loss_valid_arr = []
m = nn.Sigmoid()
for epoch in range(epochs):
    run_loss = 0
    cnt = 0
    for data in train_loader:
        X, y = data
        y = torch.reshape(y, (y.size()[0], 1))
        optimizer.zero_grad()
        outputs = net(X)
        loss = criterion(outputs, y)
        loss.backward()
        run_loss += loss
        #print(loss)
        optimizer.step()  
        cnt+=1
    if epoch % 10 == 0:
        
        run_loss = run_loss / cnt
        loss_arr.append(run_loss)
        m = nn.Sigmoid()
        validation_outputs = net(valid_x)
        valid_y = torch.reshape(valid_y, (valid_y.size()[0], 1))
        valid_loss = criterion(validation_outputs, valid_y)
        loss_valid_arr.append(valid_loss)
        print(
            f"""-------------
            Epoch {epoch},
            epoch_loss = {run_loss}
            valid_loss = {valid_loss}
        """)
        
        
print("Finished")
# Out:
# -------------
#             Epoch 0,
#             epoch_loss = 0.23681586980819702
#             valid_loss = 0.0754624456167221
#
# -------------
#             Epoch 10,
#             epoch_loss = 0.06606870889663696
#             valid_loss = 0.07280062884092331
#
# -------------
#             Epoch 20,
#             epoch_loss = 0.06545515358448029
#             valid_loss = 0.0720369964838028
#
# -------------
#             Epoch 30,
#             epoch_loss = 0.06574108451604843
#             valid_loss = 0.07073523849248886
#
# -------------
#             Epoch 40,
#             epoch_loss = 0.06523425877094269
#             valid_loss = 0.07094109803438187
#
# -------------
#             Epoch 50,
#             epoch_loss = 0.06605665385723114
#             valid_loss = 0.06878390908241272

# %%
loss_x = range(len(loss_arr))
import matplotlib.pyplot as plt
plt.plot(loss_x, loss_arr)
plt.plot(loss_x, loss_valid_arr)

# %%
m = nn.Sigmoid()
validation_outputs = net(valid_x)
valid_y = torch.reshape(valid_y, (valid_y.size()[0], 1))
valid_loss = criterion(validation_outputs, valid_y)
print(valid_loss)
out = m(validation_outputs) >= 0.5
v = valid_y == out.float()
print(torch.sum(v), torch.sum(out), valid_y.size()[0])


test_outputs = net(test_x)
test_y = torch.reshape(test_y, (test_y.size()[0], 1))
test_loss = criterion(test_outputs, test_y)
print(test_loss)

# %%
import random
num_of_example = random.choice(range(test_x.size()[0]))

# %%
import sklearn.metrics as metrics
test_outputs = m(net(test_x)) >= 0.5
print(metrics.accuracy_score(test_y, test_outputs))

# %%
#torch.save(net.state_dict(), "sunflowerClassifier.pth")
net = SunflowerFullConnectedClassificator(INPUT_SIZE, OUTPUT_SIZE)
net.load_state_dict(torch.load("sunflowerClassifier.pth"))
net.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6f605fc12340> in <module>
#       1 #torch.save(net.state_dict(), "sunflowerClassifier.pth")
# ----> 2 net = SunflowerFullConnectedClassificator(INPUT_SIZE, OUTPUT_SIZE)
#       3 net.load_state_dict(torch.load("sunflowerClassifier.pth"))
#       4 net.eval()
#
# NameError: name 'INPUT_SIZE' is not defined

# %%
import matplotlib.pyplot as plt
m = nn.Sigmoid()
for i in range(valid_x.size()[0]):
    #print((m(net(test_x[i])) >= 0.5)[0].float(),
      #       test_y[i][0])
    if (m(net(valid_x[i])) >= 0.5).item() != valid_y[i].item():
        
        plt.imshow(valid_x[i].reshape(15, 15, 3))
        print(f"Predicted class {(m(net(test_x[i])) >= 0.5)[0]}")
        print(f"Real class {test_y[i].item()}")
# Out:
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 1
# Real class 0.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
# Predicted class 0
# Real class 1.0
